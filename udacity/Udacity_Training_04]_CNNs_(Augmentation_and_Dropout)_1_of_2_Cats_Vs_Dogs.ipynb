# %% [markdown]
# <a href="https://colab.research.google.com/github/poolGolez/tf-playground/blob/main/udacity/Udacity_Training_04%5D_CNNs_(Augmentation_and_Dropout)_1_of_2_Cats_Vs_Dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import logging

import numpy as np
import matplotlib.pyplot as plt
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator

logger =  tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# # Retrieve dataset

# %%
URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filtered.zip', origin=URL, extract=True)

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs

# %%
base_dir = os.path.join(zip_dir_base, 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## Count the dataset

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))
num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

num_tr_total = num_cats_tr + num_dogs_tr
num_val_total = num_cats_val + num_dogs_val

# %%
print("Training Set] CATS:", num_cats_tr)
print("Training Set] DOGS:", num_dogs_tr)
print("Validation Set] CATS:", num_cats_val)
print("Validation Set] DOGS:", num_dogs_val)
print("===================")
print("Training Set:", num_tr_total)
print("Validation Set:", num_val_total)
# Out:
# Training Set] CATS: 1000
# Training Set] DOGS: 1000
# Validation Set] CATS: 500
# Validation Set] DOGS: 500
# ===================
# Training Set: 2000
# Validation Set: 1000

# %% [markdown]
# ## Load the dataset

# %%
BATCH_SIZE = 100
TARGET_IMAGE_SHAPE = (150, 150)

train_image_generator = ImageDataGenerator(rescale=1./255)
train_data_generator = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE, 
                                                                 directory=train_dir,
                                                                 shuffle=True, 
                                                                 target_size=TARGET_IMAGE_SHAPE, 
                                                                 class_mode='binary')

test_image_generator = ImageDataGenerator(rescale=1./255)
test_data_generator = test_image_generator.flow_from_directory(directory=validation_dir,
                                                               batch_size=BATCH_SIZE,
                                                               shuffle=False,
                                                               target_size=TARGET_IMAGE_SHAPE,
                                                               class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ## Peek at the data

# %%
sample_images,_ = next(train_data_generator)
sample_images.shape
train_data_generator.reset()

# %%
plt.figure(figsize=(30, 20))

for index,image in enumerate(sample_images[:30]):
  plt.subplot(5, 10, index+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(image)

# %% [markdown]
# #Model

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Flatten(),
  
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(2, activation='softmax')
]);

model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics='accuracy')

# %%
EPOCHS = 100
history = model.fit_generator(
    generator=train_data_generator, 
    epochs=EPOCHS, 
    steps_per_epoch=np.ceil(num_tr_total/BATCH_SIZE),
    validation_data=test_data_generator,
    validation_steps=np.ceil(num_val_total/BATCH_SIZE)
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 20/20 [==============================] - 9s 410ms/step - loss: 1.9545 - accuracy: 0.4840 - val_loss: 0.6931 - val_accuracy: 0.5050
# Epoch 2/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.6925 - accuracy: 0.5245 - val_loss: 0.6908 - val_accuracy: 0.5540
# Epoch 3/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.6920 - accuracy: 0.5650 - val_loss: 0.6909 - val_accuracy: 0.5600
# Epoch 4/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.6772 - accuracy: 0.6005 - val_loss: 0.6773 - val_accuracy: 0.5760
# Epoch 5/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.6504 - accuracy: 0.6390 - val_loss: 0.6532 - val_accuracy: 0.6340
# Epoch 6/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.5986 - accuracy: 0.6870 - val_loss: 0.6624 - val_accuracy: 0.6160
# Epoch 7/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.5553 - accuracy: 0.7160 - val_loss: 0.6052 - val_accuracy: 0.6800
# Epoch 8/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.4826 - accuracy: 0.7690 - val_loss: 0.6574 - val_accuracy: 0.6500
# Epoch 9/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.4314 - accuracy: 0.8015 - val_loss: 0.6468 - val_accuracy: 0.6730
# Epoch 10/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.3573 - accuracy: 0.8495 - val_loss: 0.6739 - val_accuracy: 0.6650
# Epoch 11/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.2981 - accuracy: 0.8775 - val_loss: 0.7405 - val_accuracy: 0.6510
# Epoch 12/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.2459 - accuracy: 0.8990 - val_loss: 0.7559 - val_accuracy: 0.6830
# Epoch 13/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.1960 - accuracy: 0.9295 - val_loss: 0.7683 - val_accuracy: 0.6700
# Epoch 14/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.1594 - accuracy: 0.9415 - val_loss: 0.8448 - val_accuracy: 0.6950
# Epoch 15/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.1475 - accuracy: 0.9440 - val_loss: 0.9765 - val_accuracy: 0.6660
# Epoch 16/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.1265 - accuracy: 0.9520 - val_loss: 0.9566 - val_accuracy: 0.6840
# Epoch 17/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.1139 - accuracy: 0.9595 - val_loss: 1.0508 - val_accuracy: 0.6660
# Epoch 18/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0865 - accuracy: 0.9710 - val_loss: 1.1794 - val_accuracy: 0.6730
# Epoch 19/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0739 - accuracy: 0.9765 - val_loss: 1.1857 - val_accuracy: 0.6640
# Epoch 20/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0605 - accuracy: 0.9810 - val_loss: 1.2364 - val_accuracy: 0.6790
# Epoch 21/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0505 - accuracy: 0.9855 - val_loss: 1.2634 - val_accuracy: 0.6780
# Epoch 22/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0470 - accuracy: 0.9850 - val_loss: 1.3303 - val_accuracy: 0.6650
# Epoch 23/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0657 - accuracy: 0.9770 - val_loss: 1.2152 - val_accuracy: 0.6720
# Epoch 24/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.0426 - accuracy: 0.9870 - val_loss: 1.3824 - val_accuracy: 0.6880
# Epoch 25/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0395 - accuracy: 0.9885 - val_loss: 1.4382 - val_accuracy: 0.6840
# Epoch 26/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0312 - accuracy: 0.9875 - val_loss: 1.4316 - val_accuracy: 0.6870
# Epoch 27/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0284 - accuracy: 0.9915 - val_loss: 1.5265 - val_accuracy: 0.6760
# Epoch 28/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0267 - accuracy: 0.9915 - val_loss: 1.4994 - val_accuracy: 0.6670
# Epoch 29/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0247 - accuracy: 0.9935 - val_loss: 1.5202 - val_accuracy: 0.6800
# Epoch 30/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0301 - accuracy: 0.9895 - val_loss: 1.5452 - val_accuracy: 0.6660
# Epoch 31/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0451 - accuracy: 0.9850 - val_loss: 1.3614 - val_accuracy: 0.6800
# Epoch 32/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0324 - accuracy: 0.9890 - val_loss: 1.4632 - val_accuracy: 0.6790
# Epoch 33/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0262 - accuracy: 0.9920 - val_loss: 1.4315 - val_accuracy: 0.6810
# Epoch 34/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0259 - accuracy: 0.9935 - val_loss: 1.4938 - val_accuracy: 0.6870
# Epoch 35/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.0207 - accuracy: 0.9925 - val_loss: 1.5593 - val_accuracy: 0.6740
# Epoch 36/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 1.6562 - val_accuracy: 0.6800
# Epoch 37/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0172 - accuracy: 0.9950 - val_loss: 1.6510 - val_accuracy: 0.6870
# Epoch 38/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.0158 - accuracy: 0.9970 - val_loss: 1.7278 - val_accuracy: 0.6890
# Epoch 39/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0235 - accuracy: 0.9945 - val_loss: 1.5623 - val_accuracy: 0.6940
# Epoch 40/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 1.4566 - val_accuracy: 0.6900
# Epoch 41/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0222 - accuracy: 0.9930 - val_loss: 1.4369 - val_accuracy: 0.6780
# Epoch 42/100
# 20/20 [==============================] - 8s 386ms/step - loss: 0.0193 - accuracy: 0.9945 - val_loss: 1.8473 - val_accuracy: 0.6810
# Epoch 43/100
# 20/20 [==============================] - 8s 401ms/step - loss: 0.0371 - accuracy: 0.9905 - val_loss: 1.3968 - val_accuracy: 0.6430
# Epoch 44/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0375 - accuracy: 0.9890 - val_loss: 1.6140 - val_accuracy: 0.6780
# Epoch 45/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0178 - accuracy: 0.9960 - val_loss: 1.5973 - val_accuracy: 0.6880
# Epoch 46/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.0102 - accuracy: 0.9980 - val_loss: 1.6671 - val_accuracy: 0.6890
# Epoch 47/100
# 20/20 [==============================] - 8s 406ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 1.6940 - val_accuracy: 0.6910
# Epoch 48/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.0192 - accuracy: 0.9955 - val_loss: 1.6014 - val_accuracy: 0.6920
# Epoch 49/100
# 20/20 [==============================] - 8s 393ms/step - loss: 0.0134 - accuracy: 0.9975 - val_loss: 1.6524 - val_accuracy: 0.6870
# Epoch 50/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 1.6988 - val_accuracy: 0.6800
# Epoch 51/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0128 - accuracy: 0.9975 - val_loss: 1.5985 - val_accuracy: 0.6880
# Epoch 52/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0089 - accuracy: 0.9980 - val_loss: 1.8308 - val_accuracy: 0.6880
# Epoch 53/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 1.7681 - val_accuracy: 0.6960
# Epoch 54/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0106 - accuracy: 0.9980 - val_loss: 1.7709 - val_accuracy: 0.7080
# Epoch 55/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 1.8984 - val_accuracy: 0.7000
# Epoch 56/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 1.7234 - val_accuracy: 0.6950
# Epoch 57/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 1.8848 - val_accuracy: 0.6870
# Epoch 58/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 1.8241 - val_accuracy: 0.6870
# Epoch 59/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 1.8274 - val_accuracy: 0.6820
# Epoch 60/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0059 - accuracy: 0.9990 - val_loss: 1.9075 - val_accuracy: 0.6800
# Epoch 61/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0098 - accuracy: 0.9980 - val_loss: 1.8893 - val_accuracy: 0.6830
# Epoch 62/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 1.7865 - val_accuracy: 0.6850
# Epoch 63/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 1.8962 - val_accuracy: 0.6900
# Epoch 64/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 1.9177 - val_accuracy: 0.6790
# Epoch 65/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 2.0644 - val_accuracy: 0.6800
# Epoch 66/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0087 - accuracy: 0.9985 - val_loss: 1.9483 - val_accuracy: 0.6730
# Epoch 67/100
# 20/20 [==============================] - 8s 393ms/step - loss: 0.0205 - accuracy: 0.9945 - val_loss: 1.5934 - val_accuracy: 0.6640
# Epoch 68/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0129 - accuracy: 0.9940 - val_loss: 1.8591 - val_accuracy: 0.6820
# Epoch 69/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 1.8691 - val_accuracy: 0.6720
# Epoch 70/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 2.0479 - val_accuracy: 0.6800
# Epoch 71/100
# 20/20 [==============================] - 8s 393ms/step - loss: 0.0096 - accuracy: 0.9945 - val_loss: 1.8943 - val_accuracy: 0.6840
# Epoch 72/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 1.9098 - val_accuracy: 0.6840
# Epoch 73/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 1.9718 - val_accuracy: 0.6660
# Epoch 74/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 1.9355 - val_accuracy: 0.6760
# Epoch 75/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 1.9893 - val_accuracy: 0.6920
# Epoch 76/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 2.1826 - val_accuracy: 0.6820
# Epoch 77/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0105 - accuracy: 0.9960 - val_loss: 1.8904 - val_accuracy: 0.6690
# Epoch 78/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 2.0082 - val_accuracy: 0.6710
# Epoch 79/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.0446 - val_accuracy: 0.6770
# Epoch 80/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0060 - accuracy: 0.9965 - val_loss: 2.1261 - val_accuracy: 0.6850
# Epoch 81/100
# 20/20 [==============================] - 8s 393ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 1.9923 - val_accuracy: 0.6690
# Epoch 82/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0084 - accuracy: 0.9990 - val_loss: 1.7897 - val_accuracy: 0.6770
# Epoch 83/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0042 - accuracy: 0.9995 - val_loss: 2.1411 - val_accuracy: 0.6780
# Epoch 84/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 2.1734 - val_accuracy: 0.6910
# Epoch 85/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 2.1402 - val_accuracy: 0.7030
# Epoch 86/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0126 - accuracy: 0.9975 - val_loss: 1.8604 - val_accuracy: 0.6790
# Epoch 87/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0089 - accuracy: 0.9990 - val_loss: 2.2133 - val_accuracy: 0.6830
# Epoch 88/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 2.2309 - val_accuracy: 0.6750
# Epoch 89/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 2.0520 - val_accuracy: 0.6630
# Epoch 90/100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.0050 - accuracy: 0.9975 - val_loss: 2.1993 - val_accuracy: 0.6750
# Epoch 91/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 2.1558 - val_accuracy: 0.6790
# Epoch 92/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 2.0109 - val_accuracy: 0.6650
# Epoch 93/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 2.0542 - val_accuracy: 0.6770
# Epoch 94/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 2.0268 - val_accuracy: 0.6820
# Epoch 95/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 2.6606 - val_accuracy: 0.6720
# Epoch 96/100
# 20/20 [==============================] - 8s 388ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.3234 - val_accuracy: 0.6760
# Epoch 97/100
# 20/20 [==============================] - 8s 387ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 2.3227 - val_accuracy: 0.6820
# Epoch 98/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 2.1896 - val_accuracy: 0.6820
# Epoch 99/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 2.6928 - val_accuracy: 0.6740
# Epoch 100/100
# 20/20 [==============================] - 8s 389ms/step - loss: 0.0044 - accuracy: 0.9985 - val_loss: 2.2947 - val_accuracy: 0.6700

# %%
plt.figure(figsize=(20, 7))

plt.subplot(1,2,1)
plt.plot(history.epoch, history.history['accuracy'], label='Training')
plt.plot(history.epoch, history.history['val_accuracy'], label='Testing')
plt.legend()
plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(history.epoch, history.history['loss'], label='Training')
plt.plot(history.epoch, history.history['val_loss'], label='Testing')
plt.legend()
plt.title("Loss")
# Out:
# Text(0.5, 1.0, 'Loss')
